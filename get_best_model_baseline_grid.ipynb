# %%
import os
import pandas as pd
import glob
import yaml

# %%
data_path = 'data'
performance_path = os.path.join(data_path, 'performance', 'baseline_grid')

# %%
selection_metric = 'auc'

# %%
def path_split(x, num_iters = 1):
    for i in range(num_iters - 1):
        x = os.path.split(x)[0]
    return os.path.split(x)[1]

# %%
files_eval = glob.glob(os.path.join(performance_path, '**', '*_eval.csv'), recursive=True)
df_eval = pd.concat({(file, path_split(file, 3), path_split(file, 2)): 
                pd.read_csv(file) for file in files_eval})
df_eval = df_eval.rename_axis(index = ['file_path', 'outcome', 'experiment_id', 'index'])

# %%
df_eval = df_eval.reset_index([0, 1, 2])

# %%
best_performance = df_eval.loc[(df_eval.metric == selection_metric) & (df_eval.phase == 'val')].groupby(['phase', 'outcome'])[['performance']].agg(max).merge(df_eval)
best_performance
# Out:
#    performance                                          file_path    outcome  \
# 0     0.850924  data/performance/baseline_grid/los/75/15523354...        los
# 1     0.905366  data/performance/baseline_grid/mortality/32/15...  mortality
#
#   experiment_id metric phase  epoch
# 0            75    auc   val      0
# 1            32    auc   val      0

# %%
df_eval.merge(best_performance[['experiment_id', 'outcome']])
# Out:
#                                             file_path    outcome  \
# 0   data/performance/baseline_grid/los/75/15523354...        los
# 1   data/performance/baseline_grid/los/75/15523354...        los
# 2   data/performance/baseline_grid/los/75/15523354...        los
# 3   data/performance/baseline_grid/los/75/15523354...        los
# 4   data/performance/baseline_grid/los/75/15523354...        los
# 5   data/performance/baseline_grid/los/75/15523354...        los
# 6   data/performance/baseline_grid/los/75/15523354...        los
# 7   data/performance/baseline_grid/los/75/15523354...        los
# 8   data/performance/baseline_grid/mortality/32/15...  mortality
# 9   data/performance/baseline_grid/mortality/32/15...  mortality
# 10  data/performance/baseline_grid/mortality/32/15...  mortality
# 11  data/performance/baseline_grid/mortality/32/15...  mortality
# 12  data/performance/baseline_grid/mortality/32/15...  mortality
# 13  data/performance/baseline_grid/mortality/32/15...  mortality
# 14  data/performance/baseline_grid/mortality/32/15...  mortality
# 15  data/performance/baseline_grid/mortality/32/15...  mortality
#
#    experiment_id metric phase  epoch  performance
# 0             75    auc   val      0     0.850924
# 1             75  auprc   val      0     0.602833
# 2             75  brier   val      0     0.117819
# 3             75   loss   val      0     0.381414
# 4             75    auc  test      0     0.854169
# 5             75  auprc  test      0     0.597652
# 6             75  brier  test      0     0.114607
# 7             75   loss  test      0     0.372925
# 8             32    auc   val      0     0.905366
# 9             32  auprc   val      0     0.232620
# 10            32  brier   val      0     0.019300
# 11            32   loss   val      0     0.083573
# 12            32    auc  test      0     0.891989
# 13            32  auprc  test      0     0.253210
# 14            32  brier  test      0     0.020807
# 15            32   loss  test      0     0.094184

# %%
best_performance[['outcome', 'experiment_id']]
# Out:
#      outcome experiment_id
# 0        los            75
# 1  mortality            32

# %%
best_model_ids = best_performance[['outcome', 'experiment_id']].set_index('outcome').transpose().to_dict('records')

# %%
best_model_ids = best_model_ids[0]
print(best_model_ids)
# Out:
# {'los': '75', 'mortality': '32'}

# %%
## Create defaults
config_path = os.path.join(data_path, 'config', 'grid', 'baseline')
config_defaults_path = os.path.join(data_path, 'config', 'defaults', 'baseline')
for the_outcome, the_model_id in best_model_ids.items():
    ## Read the best config
    with open(os.path.join(config_path, '{}.yaml'.format(the_model_id)), 'r') as fp:
        best_config = yaml.load(fp)
    temp_path = os.path.join(config_defaults_path, the_outcome)
    os.makedirs(temp_path, exist_ok = True)  
    with open(os.path.join(temp_path, 'model_config.yaml'), 'w') as fp:
        yaml.dump(best_config, fp)

# %%
files_group = glob.glob(os.path.join(performance_path, '**', '*_by_group.csv'), recursive=True)
df_group = pd.concat({(file, path_split(file, 3), path_split(file, 2)): 
                pd.read_csv(file) for file in files_group})
df_group = df_group.rename_axis(index = ['file_path', 'outcome', 'experiment_id', 'index'])
df_group = df_group.reset_index([0, 1, 2])

# %%
df_group_best = df_group.merge(best_performance[['outcome', 'experiment_id']])
df_group_best = df_group_best.loc[(df_group_best.phase == 'val') & (df_group_best.metric == 'auc')]

# %%
df_group_best
# Out:
#                                              file_path    outcome  \
# 0    data/performance/baseline_grid/los/75/15523354...        los
# 8    data/performance/baseline_grid/los/75/15523354...        los
# 16   data/performance/baseline_grid/los/75/15523354...        los
# 24   data/performance/baseline_grid/los/75/15523354...        los
# 32   data/performance/baseline_grid/los/75/15523354...        los
# 40   data/performance/baseline_grid/los/75/15523354...        los
# 48   data/performance/baseline_grid/los/75/15523354...        los
# 56   data/performance/baseline_grid/los/75/15523354...        los
# 64   data/performance/baseline_grid/los/75/15523354...        los
# 72   data/performance/baseline_grid/los/75/15523354...        los
# 80   data/performance/baseline_grid/los/75/15523354...        los
# 88   data/performance/baseline_grid/los/75/15523354...        los
# 96   data/performance/baseline_grid/mortality/32/15...  mortality
# 104  data/performance/baseline_grid/mortality/32/15...  mortality
# 112  data/performance/baseline_grid/mortality/32/15...  mortality
# 120  data/performance/baseline_grid/mortality/32/15...  mortality
# 128  data/performance/baseline_grid/mortality/32/15...  mortality
# 136  data/performance/baseline_grid/mortality/32/15...  mortality
# 144  data/performance/baseline_grid/mortality/32/15...  mortality
# 152  data/performance/baseline_grid/mortality/32/15...  mortality
# 160  data/performance/baseline_grid/mortality/32/15...  mortality
# 168  data/performance/baseline_grid/mortality/32/15...  mortality
# 176  data/performance/baseline_grid/mortality/32/15...  mortality
# 184  data/performance/baseline_grid/mortality/32/15...  mortality
#
#     experiment_id sensitive_variable  group metric phase  epoch  performance
# 0              75                age      0    auc   val      0     0.893216
# 8              75                age      1    auc   val      0     0.883370
# 16             75                age      2    auc   val      0     0.834710
# 24             75                age      3    auc   val      0     0.826948
# 32             75             gender      0    auc   val      0     0.865027
# 40             75             gender      1    auc   val      0     0.827259
# 48             75           race_eth      0    auc   val      0     0.867390
# 56             75           race_eth      1    auc   val      0     0.801317
# 64             75           race_eth      2    auc   val      0     0.861681
# 72             75           race_eth      3    auc   val      0     0.840504
# 80             75           race_eth      4    auc   val      0     0.858301
# 88             75           race_eth      5    auc   val      0     0.847649
# 96             32                age      0    auc   val      0     0.976476
# 104            32                age      1    auc   val      0     0.967324
# 112            32                age      2    auc   val      0     0.899351
# 120            32                age      3    auc   val      0     0.853760
# 128            32             gender      0    auc   val      0     0.923024
# 136            32             gender      1    auc   val      0     0.882591
# 144            32           race_eth      0    auc   val      0     0.888310
# 152            32           race_eth      1    auc   val      0     0.923964
# 160            32           race_eth      2    auc   val      0     0.925273
# 168            32           race_eth      3    auc   val      0     0.906741
# 176            32           race_eth      4    auc   val      0     0.941370
# 184            32           race_eth      5    auc   val      0     0.895081

# %%
df_group_best = df_group.merge(best_performance[['outcome', 'experiment_id']])
df_group_best = df_group_best.loc[(df_group_best.phase == 'test') & (df_group_best.metric == 'auc')]
df_group_best
# Out:
#                                              file_path    outcome  \
# 4    data/performance/baseline_grid/los/75/15523354...        los
# 12   data/performance/baseline_grid/los/75/15523354...        los
# 20   data/performance/baseline_grid/los/75/15523354...        los
# 28   data/performance/baseline_grid/los/75/15523354...        los
# 36   data/performance/baseline_grid/los/75/15523354...        los
# 44   data/performance/baseline_grid/los/75/15523354...        los
# 52   data/performance/baseline_grid/los/75/15523354...        los
# 60   data/performance/baseline_grid/los/75/15523354...        los
# 68   data/performance/baseline_grid/los/75/15523354...        los
# 76   data/performance/baseline_grid/los/75/15523354...        los
# 84   data/performance/baseline_grid/los/75/15523354...        los
# 92   data/performance/baseline_grid/los/75/15523354...        los
# 100  data/performance/baseline_grid/mortality/32/15...  mortality
# 108  data/performance/baseline_grid/mortality/32/15...  mortality
# 116  data/performance/baseline_grid/mortality/32/15...  mortality
# 124  data/performance/baseline_grid/mortality/32/15...  mortality
# 132  data/performance/baseline_grid/mortality/32/15...  mortality
# 140  data/performance/baseline_grid/mortality/32/15...  mortality
# 148  data/performance/baseline_grid/mortality/32/15...  mortality
# 156  data/performance/baseline_grid/mortality/32/15...  mortality
# 164  data/performance/baseline_grid/mortality/32/15...  mortality
# 172  data/performance/baseline_grid/mortality/32/15...  mortality
# 180  data/performance/baseline_grid/mortality/32/15...  mortality
# 188  data/performance/baseline_grid/mortality/32/15...  mortality
#
#     experiment_id sensitive_variable  group metric phase  epoch  performance
# 4              75                age      0    auc  test      0     0.882870
# 12             75                age      1    auc  test      0     0.886358
# 20             75                age      2    auc  test      0     0.856125
# 28             75                age      3    auc  test      0     0.816810
# 36             75             gender      0    auc  test      0     0.866275
# 44             75             gender      1    auc  test      0     0.834033
# 52             75           race_eth      0    auc  test      0     0.862112
# 60             75           race_eth      1    auc  test      0     0.845566
# 68             75           race_eth      2    auc  test      0     0.866527
# 76             75           race_eth      3    auc  test      0     0.837003
# 84             75           race_eth      4    auc  test      0     0.907372
# 92             75           race_eth      5    auc  test      0     0.848299
# 100            32                age      0    auc  test      0     0.826485
# 108            32                age      1    auc  test      0     0.960957
# 116            32                age      2    auc  test      0     0.899716
# 124            32                age      3    auc  test      0     0.839811
# 132            32             gender      0    auc  test      0     0.923309
# 140            32             gender      1    auc  test      0     0.852937
# 148            32           race_eth      0    auc  test      0     0.891249
# 156            32           race_eth      1    auc  test      0     0.898294
# 164            32           race_eth      2    auc  test      0     0.910245
# 172            32           race_eth      3    auc  test      0     0.928874
# 180            32           race_eth      4    auc  test      0     0.957014
# 188            32           race_eth      5    auc  test      0     0.871286
